# %% [markdown]
# <a href="https://colab.research.google.com/github/devAquino/Analise-de-dados-com-Python-e-Pandas/blob/main/Desafio_BeAnalytic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Data Engeneer Jr.

# %%
# Importação do pandas para manipulação do conjunto de daddos
import pandas as pd

# %%
# importando regular expres
import re

# %%
dados = pd.read_json('/content/drive/MyDrive/data-celi_9llyHC-1-dTorBmd.json')
dados
# Out:
#                    name           phone                           email  \
# 0          Jerry Snyder  1-963-621-3676  molestie.pharetra.nibh@aol.com
# 1         Evelyn Cortez  (438) 713-1664          eget.ipsum@outlook.org
# 2           Keane Gross  1-681-418-7743       ridiculus.mus@hotmail.net
# 3        Illana Collins  (356) 124-0101               eu@protonmail.com
# 4          Hedley Mejia  1-267-247-1174                       a@aol.org
# ..                  ...             ...                             ...
# 495        John Leonard  1-443-647-6638     ac.facilisis@protonmail.edu
# 496      Sylvia Raymond  (885) 686-6380           magna.sed@outlook.com
# 497     Kasimir Perkins  (254) 338-9683      dolor.vitae.dolor@yahoo.ca
# 498       Signe Shannon  1-656-860-4687             dapibus@outlook.edu
# 499  Cathleen Singleton  (467) 205-7385       erat.nonummy@hotmail.couk
#
#                             address postalZip                      region  \
# 0                631-6614 Quis Road   3715 CO                      Ankara
# 1                283-4910 Quis Road     69845         Zaporizhzhia oblast
# 2      P.O. Box 957, 1870 Donec St.     12528            Central Sulawesi
# 3            978-5629 Semper Street     76135                       Maule
# 4    P.O. Box 461, 9908 Luctus Road   3543 LM  Provence-Alpes-Côte d'Azur
# ..                              ...       ...                         ...
# 495     Ap #907-7737 Quisque Avenue    979592                   Andalucía
# 496          Ap #662-2621 Nisi. Av.      4032                  Puntarenas
# 497   P.O. Box 753, 4111 Risus. Ave      4648                     Abruzzo
# 498                    4932 Sit St.   K10 2DR                    Oklahoma
# 499                1378 Urna Avenue    395675                  Calabarzon
#
#          country  list  numberrange currency
# 0         France    11           10   $42.23
# 1         Sweden    13            5   $62.78
# 2         Sweden    11           10   $36.01
# 3         Sweden    13            5   $37.14
# 4         Canada     5            4   $10.49
# ..           ...   ...          ...      ...
# 495    Australia    17            0    $3.87
# 496    Australia     7            2   $75.51
# 497  Philippines     7            3   $47.15
# 498       Mexico     7            4   $92.16
# 499  Philippines    15            3   $61.74
#
# [500 rows x 10 columns]

# %% [markdown]
# *Conferindo o tipo de dado de cada coluna*

# %%
dados.dtypes
# Out:
# name           object
# phone          object
# email          object
# address        object
# postalZip      object
# region         object
# country        object
# list            int64
# numberrange     int64
# currency       object
# dtype: object

# %% [markdown]
# *Imprimindo as 10 primeiras linhas*

# %%
dados.loc[1:10]
# Out:
#                   name           phone                            email  \
# 1        Evelyn Cortez  (438) 713-1664           eget.ipsum@outlook.org
# 2          Keane Gross  1-681-418-7743        ridiculus.mus@hotmail.net
# 3       Illana Collins  (356) 124-0101                eu@protonmail.com
# 4         Hedley Mejia  1-267-247-1174                        a@aol.org
# 5          Caleb Finch  1-262-522-8138           nulla.ante@hotmail.net
# 6           Vera Terry  1-652-351-7936      neque.nullam@protonmail.net
# 7          May Jimenez  1-941-733-8663              orci.ut@outlook.edu
# 8         Porter Lucas  1-815-752-1933  suspendisse.commodo@outlook.edu
# 9   Justina Montgomery  (478) 626-8456   quis.pede.suspendisse@yahoo.ca
# 10       Isaac Gregory  (118) 494-6678           enim.etiam@hotmail.com
#
#                            address    postalZip                      region  \
# 1               283-4910 Quis Road        69845         Zaporizhzhia oblast
# 2     P.O. Box 957, 1870 Donec St.        12528            Central Sulawesi
# 3           978-5629 Semper Street        76135                       Maule
# 4   P.O. Box 461, 9908 Luctus Road      3543 LM  Provence-Alpes-Côte d'Azur
# 5               792-2262 Et Street        14980                North Island
# 6              Ap #557-5929 Eu Rd.        12328   Metropolitana de Santiago
# 7               293-7344 Velit Rd.         7379              Emilia-Romagna
# 8              1931 Posuere Avenue        66133                      Caraga
# 9                 3179 Quisque Rd.       824486                    Maranhão
# 10  P.O. Box 258, 7356 Cras Street  74541-48371                       Aydın
#
#                country  list  numberrange currency
# 1               Sweden    13            5   $62.78
# 2               Sweden    11           10   $36.01
# 3               Sweden    13            5   $37.14
# 4               Canada     5            4   $10.49
# 5   Russian Federation    19            4   $76.60
# 6       United Kingdom    17            8   $95.29
# 7          Netherlands    11            0    $5.57
# 8              Vietnam    13            6   $40.89
# 9                Chile    15            2   $86.10
# 10        South Africa    13            6   $41.54

# %% [markdown]
# *Verificando se há valores ausentes*.

# %%
dados.isnull().sum()
# Out:
# name           0
# phone          0
# email          0
# address        0
# postalZip      0
# region         0
# country        0
# list           0
# numberrange    0
# currency       0
# dtype: int64

# %% [markdown]
# ***A validação dos dados deve ocorrer de acordo com a regra de negócio, mas como é um case técnico, criarei uma condição de validação***

# %% [markdown]
# *Utilizando regex para criar máscaras para o tratamento das colunas email, phone e postalZip*

# %%
mascara_email = '^[a-z]+[\._]?[a-z0-9]+[@]\w+[.](com|edu|net|org|br)'
mascara_phone = '^[(][1-9]{2,2}[)]\s?[0-9]{5,5}-[0-9]{4,4}$'
mascara_postalZip = '^\d{5}-\d{3}$'

# %% [markdown]
# *Armazenando os valores das colunas em uma nova coluna para garantir a segurançã dos dados caso haja falhas.*

# %%
dados_postalZip = dados['postalZip']
dados_phone = dados['phone']
dados_email = dados['email']

# %%
# O postalZip deve conter 5 valores numérios um hífen e mais 3 valores numéricos.
# Se os dados nesse campo não passarem pela validação, os valores serão substituidos por 00000-000.

#Lista para armazenar os postalZips validados
postalZip_validado = []

def valida_postalZip():
  for postal_zip in dados_postalZip:
    postalZip_valido = re.search(mascara_postalZip, postal_zip)
    if postalZip_valido:
      postalZip_validado.append(postal_zip)
    else:
      postalZip_validado.append("00000-000")
  return postalZip_validado

valida_postalZip()

# %% [markdown]
# *Testando a validação do postalZip.*

# %%
postal_zip = '23469-123'

if(re.search(mascara_postalZip, postal_zip)):
    print('PostalZip certo')
else:
    print('PostalZip errado')
# Out:
# PostalZip certo

# %%
dados_postalZip = postalZip_validado

# %%
# O phone deve ter 2 números entre 1 e 9 entre parentes, representando o DDD, poderá ter espaço ou não, após o parênteses,
# 5 números entre 0 e 9 seguido de um hífen e mais 4 números entre 0 e 9.

#Lista para armazenar os telefones validados
phone_validado = []

def valida_phone():
  for phone in dados_phone:
    phone_valido = re.search(mascara_phone, phone)
    if phone_valido:
      phone_validado.append(phone)
    else:
      phone_validado.append("(00) 00000-0000")
  return phone_validado

valida_phone()
# Out:
# ['(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000',
#  '(00) 00000-0000']

# %%
phone = '(11) 22222-1234'

if(re.search(mascara_phone, phone)):
    print('Phone certo')
else:
    print('Phone errado')
# Out:
# Phone certo

# %%
dados_phone = phone_validado

# %%
# O email deve iniciar com letra minúscula, pode ter ponto final ou underscore,
# deve conter o arroba, após o arroba deve conter letras, após as letras o ponto seguido por um das
# seguintes opções: (com, edu, net, org, br) 

#Lista para armazenar os emails validados.
email_validado = []

# Função responsável pela validação dos emails.
def valida_email():
  for email in dados_email:
    email_valido = re.search(mascara_email, email)
    if email_valido:
      email_validado.append(email)
    else:
      email_validado.append("invalid email")
  return email_validado
  
valida_email()
# Out:
# ['invalid email',
#  'eget.ipsum@outlook.org',
#  'ridiculus.mus@hotmail.net',
#  'eu@protonmail.com',
#  'invalid email',
#  'nulla.ante@hotmail.net',
#  'neque.nullam@protonmail.net',
#  'orci.ut@outlook.edu',
#  'suspendisse.commodo@outlook.edu',
#  'invalid email',
#  'enim.etiam@hotmail.com',
#  'invalid email',
#  'vulputate.lacus@protonmail.net',
#  'parturient.montes@yahoo.org',
#  'ipsum@outlook.edu',
#  'ipsum@icloud.com',
#  'ut.eros@icloud.com',
#  'invalid email',
#  'semper.auctor@hotmail.net',
#  'invalid email',
#  'suspendisse.tristique@aol.com',
#  'invalid email',
#  'aliquam.erat@outlook.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'pellentesque@outlook.edu',
#  'invalid email',
#  'aenean.eget@icloud.edu',
#  'invalid email',
#  'iaculis.nec@google.edu',
#  'invalid email',
#  'sed@outlook.edu',
#  'lacus.varius@icloud.net',
#  'integer.id@icloud.org',
#  'invalid email',
#  'donec@protonmail.net',
#  'ac.nulla@yahoo.org',
#  'magna@protonmail.edu',
#  'invalid email',
#  'invalid email',
#  'nulla.facilisis@aol.net',
#  'invalid email',
#  'invalid email',
#  'magna@yahoo.org',
#  'vel.sapien@icloud.edu',
#  'duis.ac@yahoo.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'eget@aol.net',
#  'invalid email',
#  'invalid email',
#  'arcu@yahoo.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'mi@google.org',
#  'mauris.suspendisse@yahoo.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'maecenas.malesuada@outlook.com',
#  'donec@icloud.org',
#  'elit.curabitur@yahoo.net',
#  'invalid email',
#  'mauris@hotmail.org',
#  'invalid email',
#  'iaculis.aliquet@outlook.com',
#  'invalid email',
#  'invalid email',
#  'dui.suspendisse@outlook.net',
#  'invalid email',
#  'invalid email',
#  'velit.eget@hotmail.net',
#  'invalid email',
#  'invalid email',
#  'nunc@outlook.com',
#  'invalid email',
#  'odio.a@hotmail.com',
#  'ligula@protonmail.edu',
#  'invalid email',
#  'amet.orci@icloud.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'suspendisse.sagittis@google.org',
#  'invalid email',
#  'invalid email',
#  'aenean.massa@yahoo.org',
#  'invalid email',
#  'invalid email',
#  'vitae.orci@hotmail.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'etiam.imperdiet@aol.edu',
#  'aliquam@google.net',
#  'invalid email',
#  'pharetra.ut@hotmail.net',
#  'dapibus.rutrum@google.net',
#  'accumsan.laoreet@outlook.org',
#  'non@icloud.edu',
#  'sed.tortor@outlook.edu',
#  'invalid email',
#  'velit.justo@hotmail.com',
#  'invalid email',
#  'invalid email',
#  'orci.adipiscing@protonmail.net',
#  'tellus.aenean@hotmail.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'maecenas@aol.com',
#  'invalid email',
#  'invalid email',
#  'ligula.aenean@protonmail.org',
#  'invalid email',
#  'auctor.mauris@outlook.com',
#  'molestie@protonmail.com',
#  'invalid email',
#  'nunc.sollicitudin@protonmail.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'tincidunt.congue@google.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'parturient.montes@icloud.com',
#  'at.sem@icloud.net',
#  'sit.amet@google.org',
#  'invalid email',
#  'invalid email',
#  'suspendisse.aliquet@hotmail.net',
#  'invalid email',
#  'lorem@protonmail.net',
#  'invalid email',
#  'imperdiet.ornare@icloud.edu',
#  'non.dui@yahoo.edu',
#  'invalid email',
#  'amet.nulla@yahoo.edu',
#  'invalid email',
#  'at.libero@icloud.com',
#  'invalid email',
#  'invalid email',
#  'augue@outlook.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'mauris@google.org',
#  'rutrum@outlook.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'nec@yahoo.org',
#  'invalid email',
#  'invalid email',
#  'dictum.mi@icloud.net',
#  'invalid email',
#  'invalid email',
#  'arcu.iaculis@protonmail.edu',
#  'cras.lorem@yahoo.com',
#  'dictum.placerat@icloud.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'lorem.sit@icloud.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'erat@outlook.org',
#  'invalid email',
#  'invalid email',
#  'viverra.donec@hotmail.net',
#  'mauris.a@google.org',
#  'ipsum.curabitur@hotmail.com',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'rhoncus.id@protonmail.net',
#  'rutrum.eu@protonmail.com',
#  'massa.integer@aol.com',
#  'interdum.curabitur@icloud.com',
#  'molestie@aol.net',
#  'invalid email',
#  'ac@outlook.edu',
#  'invalid email',
#  'volutpat@yahoo.edu',
#  'invalid email',
#  'ipsum@google.com',
#  'invalid email',
#  'vitae.aliquam@outlook.net',
#  'non.egestas@protonmail.org',
#  'nunc@icloud.com',
#  'justo.sit@aol.edu',
#  'invalid email',
#  'arcu@icloud.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'suspendisse.tristique@icloud.edu',
#  'vel@outlook.edu',
#  'invalid email',
#  'invalid email',
#  'neque.nullam@hotmail.net',
#  'amet.ornare@aol.com',
#  'in.faucibus@aol.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'leo.in@aol.net',
#  'porttitor.eros@outlook.com',
#  'mattis@protonmail.org',
#  'invalid email',
#  'luctus.et@yahoo.edu',
#  'convallis.erat@yahoo.com',
#  'invalid email',
#  'integer.id@protonmail.org',
#  'lorem.auctor@icloud.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'vitae.mauris@yahoo.org',
#  'nascetur@protonmail.com',
#  'invalid email',
#  'amet.consectetuer@hotmail.net',
#  'quam@aol.org',
#  'quisque.imperdiet@outlook.net',
#  'invalid email',
#  'invalid email',
#  'sem.ut@protonmail.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'lacinia.mattis@yahoo.org',
#  'ipsum@aol.com',
#  'invalid email',
#  'invalid email',
#  'mollis.non@google.com',
#  'montes.nascetur@protonmail.net',
#  'invalid email',
#  'invalid email',
#  'quis.tristique@aol.com',
#  'mauris.blandit@icloud.edu',
#  'ante@hotmail.org',
#  'pellentesque.ultricies@icloud.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'libero@aol.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'dui@icloud.com',
#  'non.lobortis@protonmail.edu',
#  'invalid email',
#  'invalid email',
#  'consequat.auctor@yahoo.com',
#  'auctor.velit@aol.com',
#  'non@protonmail.com',
#  'invalid email',
#  'pede.ac@outlook.org',
#  'arcu.aliquam@google.com',
#  'invalid email',
#  'non.justo@protonmail.com',
#  'fusce.fermentum@aol.edu',
#  'invalid email',
#  'vulputate.velit@protonmail.net',
#  'invalid email',
#  'vel.lectus@aol.com',
#  'blandit.at@google.com',
#  'dolor@yahoo.org',
#  'mauris.non@google.edu',
#  'invalid email',
#  'consectetuer@protonmail.edu',
#  'penatibus.et@aol.com',
#  'invalid email',
#  'nonummy@protonmail.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'sit.amet@icloud.com',
#  'invalid email',
#  'donec@icloud.org',
#  'ut@hotmail.org',
#  'cursus@yahoo.com',
#  'invalid email',
#  'invalid email',
#  'facilisis.lorem@hotmail.edu',
#  'eget.metus@outlook.com',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'eget.massa@hotmail.org',
#  'invalid email',
#  'invalid email',
#  'donec.consectetuer@icloud.org',
#  'enim@protonmail.org',
#  'invalid email',
#  'pharetra.quisque@icloud.net',
#  'invalid email',
#  'ultrices.mauris@hotmail.org',
#  'invalid email',
#  'rutrum.lorem@yahoo.com',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'enim@protonmail.org',
#  'invalid email',
#  'auctor@aol.edu',
#  'non.enim@protonmail.edu',
#  'nulla.eget@protonmail.org',
#  'invalid email',
#  'mauris@icloud.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'vehicula.et@hotmail.org',
#  'invalid email',
#  'faucibus.orci@protonmail.edu',
#  'invalid email',
#  'et.euismod@hotmail.edu',
#  'invalid email',
#  'invalid email',
#  'sociis@protonmail.edu',
#  'aenean@yahoo.edu',
#  'quisque.nonummy@icloud.net',
#  'invalid email',
#  'ullamcorper.velit@hotmail.edu',
#  'pede@outlook.com',
#  'tortor@icloud.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'hendrerit.consectetuer@yahoo.edu',
#  'invalid email',
#  'eros.non@yahoo.edu',
#  'per.conubia@outlook.com',
#  'justo.sit@protonmail.net',
#  'phasellus.dapibus@google.edu',
#  'ac.orci@aol.org',
#  'cubilia@yahoo.edu',
#  'imperdiet.non@icloud.net',
#  'convallis.est@yahoo.net',
#  'invalid email',
#  'nec@icloud.org',
#  'eget@google.net',
#  'eu.accumsan@icloud.net',
#  'non.enim@hotmail.net',
#  'gravida.aliquam@yahoo.com',
#  'invalid email',
#  'in.lorem@google.org',
#  'ut.nulla@hotmail.net',
#  'sed.eu@outlook.net',
#  'et.magnis@google.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'elit.dictum@protonmail.edu',
#  'invalid email',
#  'varius@icloud.net',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'nulla.interdum@outlook.com',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'at.pretium@aol.com',
#  'pellentesque.habitant@google.net',
#  'invalid email',
#  'invalid email',
#  'eu@icloud.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'eu.tellus@yahoo.edu',
#  'sem.nulla@icloud.edu',
#  'pellentesque.ultricies@yahoo.com',
#  'arcu.morbi@outlook.com',
#  'enim.nunc@yahoo.edu',
#  'vulputate.dui@google.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'in@outlook.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'malesuada@yahoo.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'sagittis.nullam@aol.net',
#  'at@outlook.edu',
#  'invalid email',
#  'luctus@yahoo.org',
#  'hendrerit.id@aol.org',
#  'vitae.aliquet@outlook.net',
#  'invalid email',
#  'invalid email',
#  'duis.volutpat@outlook.net',
#  'etiam.gravida@google.com',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'eget@protonmail.com',
#  'non.lacinia@outlook.org',
#  'invalid email',
#  'nec.eleifend@hotmail.edu',
#  'invalid email',
#  'invalid email',
#  'iaculis@outlook.org',
#  'lobortis@protonmail.edu',
#  'odio.semper@aol.org',
#  'curae.phasellus@protonmail.org',
#  'invalid email',
#  'nunc.mauris@yahoo.com',
#  'invalid email',
#  'parturient.montes@icloud.com',
#  'arcu.vivamus@outlook.edu',
#  'pharetra.nibh@icloud.com',
#  'ut@aol.net',
#  'justo.sit@google.com',
#  'ultrices@google.net',
#  'invalid email',
#  'in@outlook.com',
#  'invalid email',
#  'aliquam.nisl@yahoo.edu',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'varius.ultrices@yahoo.com',
#  'lacus.etiam@protonmail.org',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'invalid email',
#  'rutrum@yahoo.edu',
#  'sem.elit@icloud.com',
#  'invalid email',
#  'est@google.org',
#  'invalid email',
#  'lorem.ipsum@outlook.net',
#  'ridiculus@aol.net',
#  'enim@aol.net',
#  'invalid email',
#  'invalid email',
#  'faucibus@google.org',
#  'invalid email',
#  'ac.facilisis@protonmail.edu',
#  'magna.sed@outlook.com',
#  'invalid email',
#  'dapibus@outlook.edu',
#  'invalid email']

# %%
email = 'a.f@hotmail.com'

if(re.search(mascara_email, email)):
    print('Endereço certo')
else:
    print('Endereço errado')
# Out:
# Endereço certo

# %%
dados_email = email_validado

# %%
dados['postalZip'] = dados_postalZip
dados['email'] = dados_email
dados['phone'] = dados_phone

# %% [markdown]
# *Agora podemos observer que no data frame os campos estão com os dados validados de acordo com minha regra de validação.*

# %%
dados
# Out:
#                    name            phone                        email  \
# 0          Jerry Snyder  (00) 00000-0000                invalid email
# 1         Evelyn Cortez  (00) 00000-0000       eget.ipsum@outlook.org
# 2           Keane Gross  (00) 00000-0000    ridiculus.mus@hotmail.net
# 3        Illana Collins  (00) 00000-0000            eu@protonmail.com
# 4          Hedley Mejia  (00) 00000-0000                invalid email
# ..                  ...              ...                          ...
# 495        John Leonard  (00) 00000-0000  ac.facilisis@protonmail.edu
# 496      Sylvia Raymond  (00) 00000-0000        magna.sed@outlook.com
# 497     Kasimir Perkins  (00) 00000-0000                invalid email
# 498       Signe Shannon  (00) 00000-0000          dapibus@outlook.edu
# 499  Cathleen Singleton  (00) 00000-0000                invalid email
#
#                             address  postalZip                      region  \
# 0                631-6614 Quis Road  00000-000                      Ankara
# 1                283-4910 Quis Road  00000-000         Zaporizhzhia oblast
# 2      P.O. Box 957, 1870 Donec St.  00000-000            Central Sulawesi
# 3            978-5629 Semper Street  00000-000                       Maule
# 4    P.O. Box 461, 9908 Luctus Road  00000-000  Provence-Alpes-Côte d'Azur
# ..                              ...        ...                         ...
# 495     Ap #907-7737 Quisque Avenue  00000-000                   Andalucía
# 496          Ap #662-2621 Nisi. Av.  00000-000                  Puntarenas
# 497   P.O. Box 753, 4111 Risus. Ave  00000-000                     Abruzzo
# 498                    4932 Sit St.  00000-000                    Oklahoma
# 499                1378 Urna Avenue  00000-000                  Calabarzon
#
#          country  list  numberrange currency
# 0         France    11           10   $42.23
# 1         Sweden    13            5   $62.78
# 2         Sweden    11           10   $36.01
# 3         Sweden    13            5   $37.14
# 4         Canada     5            4   $10.49
# ..           ...   ...          ...      ...
# 495    Australia    17            0    $3.87
# 496    Australia     7            2   $75.51
# 497  Philippines     7            3   $47.15
# 498       Mexico     7            4   $92.16
# 499  Philippines    15            3   $61.74
#
# [500 rows x 10 columns]

# %% [markdown]
# *Utilizando a api gspread para exportar para o google sheet.*

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)
work_book = gc.open_by_key('1A0dE0Fyc-gzZHIW_5c6xzoTJOvGjwJ-6RrCYPkplq2I')
work_sheet = work_book.worksheet('desafio_be_analytic')
work_sheet.update(None, dados.to_numpy().tolist())
# Out:
# {'spreadsheetId': '1A0dE0Fyc-gzZHIW_5c6xzoTJOvGjwJ-6RrCYPkplq2I',
#  'updatedCells': 5000,
#  'updatedColumns': 10,
#  'updatedRange': 'desafio_be_analytic!A1:J500',
#  'updatedRows': 500}
